# %%
import rasterio
import geopandas as gpd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from rasterio.mask import mask
from rasterio.plot import show

# %%
# Load the MODIS raster file
tif_path = "Datasets_Hackathon/MODIS_Gross_Primary_Production_GPP/2011_GP.tif"  # Modify the file path

# Open the raster and read the first band
with rasterio.open(tif_path) as src:
    gpp_data = src.read(1)
    meta = src.meta  # Get metadata
    nodata_value = 65533  # MODIS no-data value
    

# Replace no-data values with NaN
plt.imshow(gpp_data, cmap="pink")
plt.show()
